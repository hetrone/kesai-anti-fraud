# %%
import pandas as pd
df_derive = pd.read_csv('data/train_derive.csv', index_col= 'PERSONID')
df_selection = df_derive
df_selection.head()
# Out:
#                                   APPLYNO_nunique  FTR0_mean  FTR1_mean  \
# PERSONID
# 000e3ee6e04a8b18871e1c85ffab6e49               81   0.052956        0.0
# 000eba50dc8c2e3899070c6b82986814              101   0.052685        0.0
# 00139506cbd54b670e1e6dec234190e1               39   0.048932        0.0
# 0014fdb3625079de4a0d2131fd860641              153   0.065979        0.0
# 001de94e8d0d152e26ad87cb409003f9               58   0.059370        0.0
#
#                                   FTR2_mean  FTR3_mean  FTR4_mean  FTR5_mean  \
# PERSONID
# 000e3ee6e04a8b18871e1c85ffab6e49        0.0        0.0        0.0   0.000318
# 000eba50dc8c2e3899070c6b82986814        0.0        0.0        0.0   0.000198
# 00139506cbd54b670e1e6dec234190e1        0.0        0.0        0.0   0.000000
# 0014fdb3625079de4a0d2131fd860641        0.0        0.0        0.0   0.000000
# 001de94e8d0d152e26ad87cb409003f9        0.0        0.0        0.0   0.000322
#
#                                   FTR6_mean  FTR7_mean  FTR8_mean  ...    \
# PERSONID                                                           ...
# 000e3ee6e04a8b18871e1c85ffab6e49        0.0        0.0   0.000010  ...
# 000eba50dc8c2e3899070c6b82986814        0.0        0.0   0.000510  ...
# 00139506cbd54b670e1e6dec234190e1        0.0        0.0   0.000000  ...
# 0014fdb3625079de4a0d2131fd860641        0.0        0.0   0.000000  ...
# 001de94e8d0d152e26ad87cb409003f9        0.0        0.0   0.000007  ...
#
#                                   FTR44_mean  FTR45_mean  FTR46_mean  \
# PERSONID
# 000e3ee6e04a8b18871e1c85ffab6e49    0.050487         0.0         0.0
# 000eba50dc8c2e3899070c6b82986814    0.047859         0.0         0.0
# 00139506cbd54b670e1e6dec234190e1    0.048932         0.0         0.0
# 0014fdb3625079de4a0d2131fd860641    0.063276         0.0         0.0
# 001de94e8d0d152e26ad87cb409003f9    0.047876         0.0         0.0
#
#                                   FTR47_mean  FTR48_mean  FTR49_mean  \
# PERSONID
# 000e3ee6e04a8b18871e1c85ffab6e49    0.000010    0.047401         0.0
# 000eba50dc8c2e3899070c6b82986814    0.000004    0.047860         0.0
# 00139506cbd54b670e1e6dec234190e1    0.000026    0.066026         0.0
# 0014fdb3625079de4a0d2131fd860641    0.000676    0.046481         0.0
# 001de94e8d0d152e26ad87cb409003f9    0.000028    0.047876         0.0
#
#                                   FTR50_mean  FTR51_nunique  \
# PERSONID
# 000e3ee6e04a8b18871e1c85ffab6e49    0.000000             42
# 000eba50dc8c2e3899070c6b82986814    0.000000             50
# 00139506cbd54b670e1e6dec234190e1    0.000000             21
# 0014fdb3625079de4a0d2131fd860641    0.000000             51
# 001de94e8d0d152e26ad87cb409003f9    0.000138             31
#
#                                   CREATETIME_nunique  LABEL
# PERSONID
# 000e3ee6e04a8b18871e1c85ffab6e49                  19    0.0
# 000eba50dc8c2e3899070c6b82986814                  50    0.0
# 00139506cbd54b670e1e6dec234190e1                  26    0.0
# 0014fdb3625079de4a0d2131fd860641                  62    2.0
# 001de94e8d0d152e26ad87cb409003f9                  29    0.0
#
# [5 rows x 55 columns]

# %%
df_selection.to_csv('data/train_selection.csv')
